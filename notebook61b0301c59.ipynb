# %% [markdown]
# <span style="font-size: 100px;">K-nearest neighbors</span>

# %% [markdown]
# ![Untitled.png](attachment:fc5762eb-638a-434d-80fd-3d6f286e03f6.png)

# %% [markdown]
# ![Untitled.png](attachment:d687b6ae-2a1b-4a2b-b915-3a3cb3b963aa.png)

# %% [markdown]
# ![Untitled.png](attachment:36d6709c-3990-457b-84c9-49d71eda8d8b.png)
